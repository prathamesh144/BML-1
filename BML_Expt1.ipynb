# %% [markdown]
# <a href="https://colab.research.google.com/github/Manthan26-cmd/BML/blob/main/BML_Expt1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extract the data from the database using python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/Data_Science/Netflix_data.csv')

# %%
data.head()
# Out:
#                                    title   type                     genres  \
# 0                      The Fifth Element  movie  Action, Adventure, Sci-Fi
# 1                      Kill Bill: Vol. 1  movie    Action, Crime, Thriller
# 2                                Jarhead  movie      Biography, Drama, War
# 3                             Unforgiven  movie             Drama, Western
# 4  Eternal Sunshine of the Spotless Mind  movie     Drama, Romance, Sci-Fi
#
#    releaseYear     imdbId  imdbAverageRating  imdbNumVotes  \
# 0       1997.0  tt0119116                7.6      518984.0
# 1       2003.0  tt0266697                8.2     1227719.0
# 2       2005.0  tt0418763                7.0      212629.0
# 3       1992.0  tt0105695                8.2      446373.0
# 4       2004.0  tt0338013                8.3     1112555.0
#
#                                   availableCountries
# 0                                         AT, CH, DE
# ...

# %%
data.tail()
# Out:
#                   title type       genres  releaseYear      imdbId  \
# 20485               NaN   tv    Animation       2016.0         NaN
# 20486               NaN   tv    Animation       2005.0         NaN
# 20487  La Vida es Sueño   tv  Documentary       2024.0  tt32268206
# 20488               NaN   tv          NaN       2021.0         NaN
# 20489               NaN   tv          NaN       2022.0         NaN
#
#        imdbAverageRating  imdbNumVotes  \
# 20485                NaN           NaN
# 20486                NaN           NaN
# 20487                NaN           NaN
# 20488                NaN           NaN
# 20489                NaN           NaN
#
#                                       availableCountries
# 20485  FJ, HK, ID, IN, JP, KR, MU, MY, PH, PK, SG, TH...
# 20486                                             JP, KR
# 20487  AR, BO, CL, CO, CR, CU, DO, EC, GT, HN, MX, NI...
# 20488                                                 US
# ...

# %%
data.describe()
# Out:
#         releaseYear  imdbAverageRating  imdbNumVotes
# count  20469.000000       18918.000000  1.891800e+04
# mean    2013.076701           6.398605  3.154563e+04
# std       14.380045           1.095876  1.194369e+05
# min     1913.000000           1.200000  5.000000e+00
# 25%     2011.000000           5.700000  3.310000e+02
# 50%     2018.000000           6.500000  1.594500e+03
# 75%     2021.000000           7.200000  1.014125e+04
# max     2025.000000           9.500000  2.978913e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20490 entries, 0 to 20489
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               19927 non-null  object
#  1   type                20490 non-null  object
#  2   genres              20187 non-null  object
#  3   releaseYear         20469 non-null  float64
#  4   imdbId              19081 non-null  object
#  5   imdbAverageRating   18918 non-null  float64
#  6   imdbNumVotes        18918 non-null  float64
#  7   availableCountries  20490 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 1.3+ MB

# %%
data.size
# Out:
# 163920

# %%
data.shape
# Out:
# (20490, 8)
